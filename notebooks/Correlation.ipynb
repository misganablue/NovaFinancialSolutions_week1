# %%
# !pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: nltk>=3.8 in d:\ai_matery_10acadamy\novafinancialsolutions_week1\.venv\lib\site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in d:\ai_matery_10acadamy\novafinancialsolutions_week1\.venv\lib\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Requirement already satisfied: joblib in d:\ai_matery_10acadamy\novafinancialsolutions_week1\.venv\lib\site-packages (from nltk>=3.8->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in d:\ai_matery_10acadamy\novafinancialsolutions_week1\.venv\lib\site-packages (from nltk>=3.8->textblob) (2024.7.24)
# Requirement already satisfied: tqdm in d:\ai_matery_10acadamy\novafinancialsolutions_week1\.venv\lib\site-packages (from nltk>=3.8->textblob) (4.66.5)
# Requirement already satisfied: colorama in d:\ai_matery_10acadamy\novafinancialsolutions_week1\.venv\lib\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    -------------------------------- ------ 524.3/626.3 kB 38.3 kB/s eta 0:00:03
#    --------------------------------------- 626.3/626.3 kB 33.3 kB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.18.0.post0

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from textblob import TextBlob

# Define the ticker and the time period
ticker = 'AAPL'
start_date = '2020-01-01'
end_date = '2023-01-01'

# Fetch the stock data
aapl_data = yf.download(ticker, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Set the random seed for reproducibility
np.random.seed(0)

# Create a DataFrame with dates from the AAPL data
dates = aapl_data.index
text_data = pd.DataFrame(dates, columns=['Date'])

# %%
# Generate random headlines
headline_samples = [
    "AAPL hits record high",
    "Concerns over AAPL's future growth",
    "AAPL to unveil new product next month",
    "AAPL reports earnings that exceed forecasts",
    "Market downturn affects AAPL",
    "AAPL invests in renewable energy",
    "New AAPL CEO announced",
    "AAPL faces regulatory scrutiny",
    "AAPL rumored to acquire a tech startup",
    "AAPL's market share grows"
]

# Assign a random headline to each date
text_data['Headline'] = np.random.choice(headline_samples, size=len(text_data))

# Display the first few rows of the updated DataFrame
text_data.head()
# Out:
#         Date                                     Headline
# 0 2020-01-02             AAPL invests in renewable energy
# 1 2020-01-03                        AAPL hits record high
# 2 2020-01-06  AAPL reports earnings that exceed forecasts
# 3 2020-01-07  AAPL reports earnings that exceed forecasts
# 4 2020-01-08               AAPL faces regulatory scrutiny

# %%
def calculate_sentiment(text):
    return TextBlob(text).sentiment.polarity

# Applying the sentiment analysis function to your headlines
text_data['Sentiment'] = text_data['Headline'].apply(calculate_sentiment)

# %%
# Aligning sentiment scores with the stock closing prices on the same date
combined_data = text_data.set_index('Date').join(aapl_data['Close'])
combined_data.head()
# Out:
#                                                Headline  Sentiment      Close
# Date
# 2020-01-02             AAPL invests in renewable energy       0.00  75.087502
# 2020-01-03                        AAPL hits record high       0.16  74.357498
# 2020-01-06  AAPL reports earnings that exceed forecasts       0.00  74.949997
# 2020-01-07  AAPL reports earnings that exceed forecasts       0.00  74.597504
# 2020-01-08               AAPL faces regulatory scrutiny       0.00  75.797501

# %%
combined_data['Daily Returns'] = combined_data['Close'].pct_change()

# %%
correlation = combined_data['Sentiment'].corr(combined_data['Daily Returns'])
print("Correlation between sentiment and daily stock returns:", correlation)
# Out:
# Correlation between sentiment and daily stock returns: 0.014483000048835794

# %%
correlation = combined_data['Sentiment'].corr(combined_data['Close'])
print("Correlation between sentiment and closing:", correlation)
# Out:
# Correlation between sentiment and closing: 0.0368830047479857
